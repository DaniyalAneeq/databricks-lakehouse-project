# %% [markdown]
# ## Orchestration Logic
#
# This notebook programmatically runs all Silver transformation notebooks in sequence.
# It becomes the single entry point for the Silver layer in Databricks Jobs.

# %%
notebooks = [
    "./crm/crm_cust_info_silver",
    "./crm/crm_prd_info_silver",
    "./crm/crm_sales_details_silver",
    "./erp/erp_cust_az12_silver",
    "./erp/erp_loc_a101_silver",
    "./erp/erp_px_cat_g1v2_silver"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
